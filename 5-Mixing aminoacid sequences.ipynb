# %%
import pandas as pd

# %%
df = pd.read_csv("seq.csv")
df.head()
# Out:
#                                             sequence
# 0  ACWDNBFLKFNVNFSNSNVNFVNDFLKNSLCVNDKVNFNVRJDNSN...
# 1  SKNVJJNVGFBNBNNVFKVDNVKLGNBFGLKTLREFMVKLDFMVDK...
# 2  SDVDVFNDFKLNDFKLVNS'KVNDKJVNJKBNTGNGRTIJGIORJF...
# 3  DIFJVDFNJVKFNBFGJNBSXJFIJAIDFIVGFJBNSDJVNFJVBF...
# 4  JNFVJKDNV JKDN VKJDN KJDFNVJDFVNNVJDFVBNHUIHEI...

# %%
import random

# %%
df["mixed sequence"]= df["sequence"].apply(lambda row: random.sample(row, k=10))
df.head()
# Out:
#                                             sequence  \
# 0  ACWDNBFLKFNVNFSNSNVNFVNDFLKNSLCVNDKVNFNVRJDNSN...
# 1  SKNVJJNVGFBNBNNVFKVDNVKLGNBFGLKTLREFMVKLDFMVDK...
# 2  SDVDVFNDFKLNDFKLVNS'KVNDKJVNJKBNTGNGRTIJGIORJF...
# 3  DIFJVDFNJVKFNBFGJNBSXJFIJAIDFIVGFJBNSDJVNFJVBF...
# 4  JNFVJKDNV JKDN VKJDN KJDFNVJDFVNNVJDFVBNHUIHEI...
#
#                    mixed sequence
# 0  [N, F, M, V, S, D, N, N, K, N]
# 1  [N, N, S, M, K, G, V, R, B, K]
# 2  [K, N, N, G, S, N, S, V, V, D]
# 3  [N, V, F, V, X, N, D, J, B, V]
# 4  [D, I, N, E, F, E, U, J, K, B]

# %%
df["combined"]= df["mixed sequence"].apply(lambda row:"".join(row))

# %%
df.head()
# Out:
#                                             sequence  \
# 0  ACWDNBFLKFNVNFSNSNVNFVNDFLKNSLCVNDKVNFNVRJDNSN...
# 1  SKNVJJNVGFBNBNNVFKVDNVKLGNBFGLKTLREFMVKLDFMVDK...
# 2  SDVDVFNDFKLNDFKLVNS'KVNDKJVNJKBNTGNGRTIJGIORJF...
# 3  DIFJVDFNJVKFNBFGJNBSXJFIJAIDFIVGFJBNSDJVNFJVBF...
# 4  JNFVJKDNV JKDN VKJDN KJDFNVJDFVNNVJDFVBNHUIHEI...
#
#                    mixed sequence    combined
# 0  [N, F, M, V, S, D, N, N, K, N]  NFMVSDNNKN
# 1  [N, N, S, M, K, G, V, R, B, K]  NNSMKGVRBK
# 2  [K, N, N, G, S, N, S, V, V, D]  KNNGSNSVVD
# 3  [N, V, F, V, X, N, D, J, B, V]  NVFVXNDJBV
# 4  [D, I, N, E, F, E, U, J, K, B]  DINEFEUJKB

# %%
df.to_excel(r"C:\Users\Admin\Desktop\Биоинформатика\Научка\mixed sequences.xlsx", index= False)
